# %% [markdown]
# # Binary Decision Trees for Entropy Intuition
#
# Visualizing why uniform distributions need more questions than biased ones.

# %%
import matplotlib.pyplot as plt
from alhikmah_llms import Session2

# %% [markdown]
# ### Case 1: Uniform Distribution (1-8, each p=0.125)
#
# Binary search tree - always takes 3 questions

# %%
Session2.draw_uniform_tree()
plt.show()

# %% [markdown]
# ### Case 2: Biased Distribution (50% is 1, rest split among 2-8)
#
# Optimized tree - check the most likely outcome first

# %%
Session2.draw_biased_tree()
plt.show()

# %% [markdown]
# ## Side-by-Side Comparison

# %%
Session2.draw_comparison()
plt.show()

# %% [markdown]
# ## Probability Distributions
#
# Visualize the underlying probability distributions

# %%
Session2.plot_distributions()
plt.show()

print("\n🎯 Key Observation:")
print("   The more 'spiky' the distribution, the lower the entropy.")
print("   Uniform = maximum entropy = maximum unpredictability")
print("   Biased = lower entropy = more predictable = easier to guess")

# %% [markdown]
# ## Compression Visualization
#
# Shows how entropy-based encoding saves space

# %%
Session2.plot_compression_example()
plt.show()

# %% [markdown]
# ## Surprise Visualizations

# %%
Session2.plot_surprise_curve()
plt.show()

# %% [markdown]
# ## Entropy in Different Dimensions
#
# ### 1D: Binary Entropy Function
#
# The most fundamental curve in information theory

# %%
Session2.plot_binary_entropy()
plt.show()

print("\n🎯 Key Observation:")
print("   Maximum entropy at p=0.5 (coin flip)")
print("   Zero entropy at p=0 or p=1 (certain)")
print("   This symmetric curve is the foundation of all entropy calculations!")

# %% [markdown]
# ### 2D: Ternary/Simplex Plot
#
# Shows entropy for all possible 3-outcome distributions (like RPS)

# %%
Session2.plot_ternary_entropy_3d_plotly().show()

print("\n🎯 Key Observation:")
print("   Click and drag to rotate the 3D surface!")
print("   Peak at center (uniform) = maximum entropy")
print("   Three valleys at corners (certain) = zero entropy")
print("   Beautiful mountain-like surface!")
